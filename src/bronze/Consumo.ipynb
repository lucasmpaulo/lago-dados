# %%
display(spark.sql(f"SELECT * FROM bronze.customers"))

# %%
display(spark.sql(f"SELECT * FROM bronze.transactions ORDER BY DtCriacao DESC"))

# %%
display(spark.sql(f"SELECT * FROM bronze.transactions_product"))
